# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork899-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# -   Collect exchange rate data using an API
# -   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd
import json
import seaborn as sns
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
# 1. Open the url : https://exchangeratesapi.io/ and click on **Get Free API Key**.
# 2. Subscribe for Free plan and Sign-in with the Google Account.
# 3. Once the account is created you will be redirected to https://apilayer.com website.
# 2. Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png">
#
# 3. Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
#  <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Write your code here
url = "http://api.exchangeratesapi.io/v1/latest?base=EUR&access_key=f6f955a930732a6526a64e6f0fd0c7a7"  #Make sure to change ******* to your API key.
data = requests.get(url).text
data
# Out:
# '{"success":true,"timestamp":1692934326,"base":"EUR","date":"2023-08-25","rates":{"AED":3.961143,"AFN":90.085381,"ALL":109.54913,"AMD":419.509837,"ANG":1.954482,"AOA":891.879568,"ARS":377.432964,"AUD":1.681722,"AWG":1.941214,"AZN":1.83045,"BAM":1.954001,"BBD":2.189684,"BDT":118.480906,"BGN":1.95534,"BHD":0.406542,"BIF":3075.511115,"BMD":1.078452,"BND":1.467122,"BOB":7.49403,"BRL":5.264789,"BSD":1.084501,"BTC":4.137031e-5,"BTN":89.504357,"BWP":14.595561,"BYN":2.737305,"BYR":21137.659004,"BZD":2.186007,"CAD":1.46643,"CDF":2679.953102,"CHF":0.955619,"CLF":0.03323,"CLP":916.910902,"CNY":7.85879,"COP":4402.241023,"CRC":584.850639,"CUC":1.078452,"CUP":28.578978,"CVE":110.162544,"CZK":24.150692,"DJF":193.092206,"DKK":7.453774,"DOP":61.50223,"DZD":147.310198,"EGP":33.326598,"ERN":16.17678,"ETB":59.664033,"EUR":1,"FJD":2.444473,"FKP":0.853702,"GBP":0.858065,"GEL":2.841754,"GGP":0.853702,"GHS":12.308552,"GIP":0.853702,"GMD":65.624198,"GNF":9314.250951,"GTQ":8.51608,"GYD":227.068816,"HKD":8.458892,"HNL":26.697047,"HRK":7.42277,"HTG":146.941975,"HUF":383.907841,"IDR":16494.923187,"ILS":4.094764,"IMP":0.853702,"INR":89.133516,"IQD":1420.30539,"IRR":45591.558142,"ISK":143.099443,"JEP":0.853702,"JMD":167.004678,"JOD":0.763526,"JPY":157.475016,"KES":156.28557,"KGS":95.148803,"KHR":4495.777033,"KMF":490.695751,"KPW":970.521404,"KRW":1431.881999,"KWD":0.332808,"KYD":0.903776,"KZT":498.305794,"LAK":21201.448143,"LBP":16372.493916,"LKR":351.919225,"LRD":200.592033,"LSL":19.961738,"LTL":3.184388,"LVL":0.652345,"LYD":5.230184,"MAD":10.822734,"MDL":19.303226,"MGA":4905.437717,"MKD":61.482641,"MMK":2277.403028,"MNT":3745.430034,"MOP":8.759915,"MRO":385.007175,"MUR":49.362996,"MVR":16.611566,"MWK":1176.905424,"MXN":18.152062,"MYR":5.018079,"MZN":68.212035,"NAD":19.961714,"NGN":814.997142,"NIO":39.672735,"NOK":11.58464,"NPR":143.205484,"NZD":1.823916,"OMR":0.415203,"PAB":1.084501,"PEN":4.014204,"PGK":3.969272,"PHP":61.088927,"PKR":325.722483,"PLN":4.478133,"PYG":7892.732581,"QAR":3.926658,"RON":4.939202,"RSD":117.298913,"RUB":101.921593,"RWF":1290.00024,"SAR":4.045726,"SBD":9.026125,"SCR":14.291701,"SDG":648.662348,"SEK":11.894366,"SGD":1.463799,"SHP":1.312206,"SLE":23.617652,"SLL":21299.426986,"SOS":613.10694,"SSP":648.684859,"SRD":41.192011,"STD":22321.778807,"SYP":14127.618768,"SZL":20.160437,"THB":37.863997,"TJS":11.902251,"TMT":3.785366,"TND":3.335115,"TOP":2.57588,"TRY":27.881431,"TTD":7.364287,"TWD":34.329392,"TZS":2701.395008,"UAH":40.055646,"UGX":4023.258185,"USD":1.078452,"UYU":41.041829,"UZS":13086.949884,"VEF":3465939.528886,"VES":34.659638,"VND":25888.24002,"VUV":130.684735,"WST":2.993181,"XAF":655.347497,"XAG":0.044859,"XAU":0.000563,"XCD":2.91457,"XDR":0.815442,"XOF":655.353568,"XPF":119.406241,"YER":269.990358,"ZAR":20.33267,"ZMK":9707.364242,"ZMW":21.22865,"ZWL":347.261101}}'

# %%
data = json.loads(data)
data
# Out:
# {'success': True,
#  'timestamp': 1692934326,
#  'base': 'EUR',
#  'date': '2023-08-25',
#  'rates': {'AED': 3.961143,
#   'AFN': 90.085381,
#   'ALL': 109.54913,
#   'AMD': 419.509837,
#   'ANG': 1.954482,
#   'AOA': 891.879568,
#   'ARS': 377.432964,
#   'AUD': 1.681722,
#   'AWG': 1.941214,
#   'AZN': 1.83045,
#   'BAM': 1.954001,
#   'BBD': 2.189684,
#   'BDT': 118.480906,
#   'BGN': 1.95534,
#   'BHD': 0.406542,
#   'BIF': 3075.511115,
#   'BMD': 1.078452,
#   'BND': 1.467122,
#   'BOB': 7.49403,
#   'BRL': 5.264789,
#   'BSD': 1.084501,
#   'BTC': 4.137031e-05,
#   'BTN': 89.504357,
#   'BWP': 14.595561,
#   'BYN': 2.737305,
#   'BYR': 21137.659004,
#   'BZD': 2.186007,
#   'CAD': 1.46643,
#   'CDF': 2679.953102,
#   'CHF': 0.955619,
#   'CLF': 0.03323,
#   'CLP': 916.910902,
#   'CNY': 7.85879,
#   'COP': 4402.241023,
#   'CRC': 584.850639,
#   'CUC': 1.078452,
#   'CUP': 28.578978,
#   'CVE': 110.162544,
#   'CZK': 24.150692,
#   'DJF': 193.092206,
#   'DKK': 7.453774,
#   'DOP': 61.50223,
#   'DZD': 147.310198,
#   'EGP': 33.326598,
#   'ERN': 16.17678,
#   'ETB': 59.664033,
#   'EUR': 1,
#   'FJD': 2.444473,
#   'FKP': 0.853702,
#   'GBP': 0.858065,
#   'GEL': 2.841754,
#   'GGP': 0.853702,
#   'GHS': 12.308552,
#   'GIP': 0.853702,
#   'GMD': 65.624198,
#   'GNF': 9314.250951,
#   'GTQ': 8.51608,
#   'GYD': 227.068816,
#   'HKD': 8.458892,
#   'HNL': 26.697047,
#   'HRK': 7.42277,
#   'HTG': 146.941975,
#   'HUF': 383.907841,
#   'IDR': 16494.923187,
#   'ILS': 4.094764,
#   'IMP': 0.853702,
#   'INR': 89.133516,
#   'IQD': 1420.30539,
#   'IRR': 45591.558142,
#   'ISK': 143.099443,
#   'JEP': 0.853702,
#   'JMD': 167.004678,
#   'JOD': 0.763526,
#   'JPY': 157.475016,
#   'KES': 156.28557,
#   'KGS': 95.148803,
#   'KHR': 4495.777033,
#   'KMF': 490.695751,
#   'KPW': 970.521404,
#   'KRW': 1431.881999,
#   'KWD': 0.332808,
#   'KYD': 0.903776,
#   'KZT': 498.305794,
#   'LAK': 21201.448143,
#   'LBP': 16372.493916,
#   'LKR': 351.919225,
#   'LRD': 200.592033,
#   'LSL': 19.961738,
#   'LTL': 3.184388,
#   'LVL': 0.652345,
#   'LYD': 5.230184,
#   'MAD': 10.822734,
#   'MDL': 19.303226,
#   'MGA': 4905.437717,
#   'MKD': 61.482641,
#   'MMK': 2277.403028,
#   'MNT': 3745.430034,
#   'MOP': 8.759915,
#   'MRO': 385.007175,
#   'MUR': 49.362996,
#   'MVR': 16.611566,
#   'MWK': 1176.905424,
#   'MXN': 18.152062,
#   'MYR': 5.018079,
#   'MZN': 68.212035,
#   'NAD': 19.961714,
#   'NGN': 814.997142,
#   'NIO': 39.672735,
#   'NOK': 11.58464,
#   'NPR': 143.205484,
#   'NZD': 1.823916,
#   'OMR': 0.415203,
#   'PAB': 1.084501,
#   'PEN': 4.014204,
#   'PGK': 3.969272,
#   'PHP': 61.088927,
#   'PKR': 325.722483,
#   'PLN': 4.478133,
#   'PYG': 7892.732581,
#   'QAR': 3.926658,
#   'RON': 4.939202,
#   'RSD': 117.298913,
#   'RUB': 101.921593,
#   'RWF': 1290.00024,
#   'SAR': 4.045726,
#   'SBD': 9.026125,
#   'SCR': 14.291701,
#   'SDG': 648.662348,
#   'SEK': 11.894366,
#   'SGD': 1.463799,
#   'SHP': 1.312206,
#   'SLE': 23.617652,
#   'SLL': 21299.426986,
#   'SOS': 613.10694,
#   'SSP': 648.684859,
#   'SRD': 41.192011,
#   'STD': 22321.778807,
#   'SYP': 14127.618768,
#   'SZL': 20.160437,
#   'THB': 37.863997,
#   'TJS': 11.902251,
#   'TMT': 3.785366,
#   'TND': 3.335115,
#   'TOP': 2.57588,
#   'TRY': 27.881431,
#   'TTD': 7.364287,
#   'TWD': 34.329392,
#   'TZS': 2701.395008,
#   'UAH': 40.055646,
#   'UGX': 4023.258185,
#   'USD': 1.078452,
#   'UYU': 41.041829,
#   'UZS': 13086.949884,
#   'VEF': 3465939.528886,
#   'VES': 34.659638,
#   'VND': 25888.24002,
#   'VUV': 130.684735,
#   'WST': 2.993181,
#   'XAF': 655.347497,
#   'XAG': 0.044859,
#   'XAU': 0.000563,
#   'XCD': 2.91457,
#   'XDR': 0.815442,
#   'XOF': 655.353568,
#   'XPF': 119.406241,
#   'YER': 269.990358,
#   'ZAR': 20.33267,
#   'ZMK': 9707.364242,
#   'ZMW': 21.22865,
#   'ZWL': 347.261101}}

# %%
data['rates']
# Out:
# {'AED': 3.961143,
#  'AFN': 90.085381,
#  'ALL': 109.54913,
#  'AMD': 419.509837,
#  'ANG': 1.954482,
#  'AOA': 891.879568,
#  'ARS': 377.432964,
#  'AUD': 1.681722,
#  'AWG': 1.941214,
#  'AZN': 1.83045,
#  'BAM': 1.954001,
#  'BBD': 2.189684,
#  'BDT': 118.480906,
#  'BGN': 1.95534,
#  'BHD': 0.406542,
#  'BIF': 3075.511115,
#  'BMD': 1.078452,
#  'BND': 1.467122,
#  'BOB': 7.49403,
#  'BRL': 5.264789,
#  'BSD': 1.084501,
#  'BTC': 4.137031e-05,
#  'BTN': 89.504357,
#  'BWP': 14.595561,
#  'BYN': 2.737305,
#  'BYR': 21137.659004,
#  'BZD': 2.186007,
#  'CAD': 1.46643,
#  'CDF': 2679.953102,
#  'CHF': 0.955619,
#  'CLF': 0.03323,
#  'CLP': 916.910902,
#  'CNY': 7.85879,
#  'COP': 4402.241023,
#  'CRC': 584.850639,
#  'CUC': 1.078452,
#  'CUP': 28.578978,
#  'CVE': 110.162544,
#  'CZK': 24.150692,
#  'DJF': 193.092206,
#  'DKK': 7.453774,
#  'DOP': 61.50223,
#  'DZD': 147.310198,
#  'EGP': 33.326598,
#  'ERN': 16.17678,
#  'ETB': 59.664033,
#  'EUR': 1,
#  'FJD': 2.444473,
#  'FKP': 0.853702,
#  'GBP': 0.858065,
#  'GEL': 2.841754,
#  'GGP': 0.853702,
#  'GHS': 12.308552,
#  'GIP': 0.853702,
#  'GMD': 65.624198,
#  'GNF': 9314.250951,
#  'GTQ': 8.51608,
#  'GYD': 227.068816,
#  'HKD': 8.458892,
#  'HNL': 26.697047,
#  'HRK': 7.42277,
#  'HTG': 146.941975,
#  'HUF': 383.907841,
#  'IDR': 16494.923187,
#  'ILS': 4.094764,
#  'IMP': 0.853702,
#  'INR': 89.133516,
#  'IQD': 1420.30539,
#  'IRR': 45591.558142,
#  'ISK': 143.099443,
#  'JEP': 0.853702,
#  'JMD': 167.004678,
#  'JOD': 0.763526,
#  'JPY': 157.475016,
#  'KES': 156.28557,
#  'KGS': 95.148803,
#  'KHR': 4495.777033,
#  'KMF': 490.695751,
#  'KPW': 970.521404,
#  'KRW': 1431.881999,
#  'KWD': 0.332808,
#  'KYD': 0.903776,
#  'KZT': 498.305794,
#  'LAK': 21201.448143,
#  'LBP': 16372.493916,
#  'LKR': 351.919225,
#  'LRD': 200.592033,
#  'LSL': 19.961738,
#  'LTL': 3.184388,
#  'LVL': 0.652345,
#  'LYD': 5.230184,
#  'MAD': 10.822734,
#  'MDL': 19.303226,
#  'MGA': 4905.437717,
#  'MKD': 61.482641,
#  'MMK': 2277.403028,
#  'MNT': 3745.430034,
#  'MOP': 8.759915,
#  'MRO': 385.007175,
#  'MUR': 49.362996,
#  'MVR': 16.611566,
#  'MWK': 1176.905424,
#  'MXN': 18.152062,
#  'MYR': 5.018079,
#  'MZN': 68.212035,
#  'NAD': 19.961714,
#  'NGN': 814.997142,
#  'NIO': 39.672735,
#  'NOK': 11.58464,
#  'NPR': 143.205484,
#  'NZD': 1.823916,
#  'OMR': 0.415203,
#  'PAB': 1.084501,
#  'PEN': 4.014204,
#  'PGK': 3.969272,
#  'PHP': 61.088927,
#  'PKR': 325.722483,
#  'PLN': 4.478133,
#  'PYG': 7892.732581,
#  'QAR': 3.926658,
#  'RON': 4.939202,
#  'RSD': 117.298913,
#  'RUB': 101.921593,
#  'RWF': 1290.00024,
#  'SAR': 4.045726,
#  'SBD': 9.026125,
#  'SCR': 14.291701,
#  'SDG': 648.662348,
#  'SEK': 11.894366,
#  'SGD': 1.463799,
#  'SHP': 1.312206,
#  'SLE': 23.617652,
#  'SLL': 21299.426986,
#  'SOS': 613.10694,
#  'SSP': 648.684859,
#  'SRD': 41.192011,
#  'STD': 22321.778807,
#  'SYP': 14127.618768,
#  'SZL': 20.160437,
#  'THB': 37.863997,
#  'TJS': 11.902251,
#  'TMT': 3.785366,
#  'TND': 3.335115,
#  'TOP': 2.57588,
#  'TRY': 27.881431,
#  'TTD': 7.364287,
#  'TWD': 34.329392,
#  'TZS': 2701.395008,
#  'UAH': 40.055646,
#  'UGX': 4023.258185,
#  'USD': 1.078452,
#  'UYU': 41.041829,
#  'UZS': 13086.949884,
#  'VEF': 3465939.528886,
#  'VES': 34.659638,
#  'VND': 25888.24002,
#  'VUV': 130.684735,
#  'WST': 2.993181,
#  'XAF': 655.347497,
#  'XAG': 0.044859,
#  'XAU': 0.000563,
#  'XCD': 2.91457,
#  'XDR': 0.815442,
#  'XOF': 655.353568,
#  'XPF': 119.406241,
#  'YER': 269.990358,
#  'ZAR': 20.33267,
#  'ZMK': 9707.364242,
#  'ZMW': 21.22865,
#  'ZWL': 347.261101}

# %% [markdown]
# ### Save as DataFrame
#
#  <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Turn the data into a dataframe
df = pd.DataFrame(columns = ['Currency', 'Rate'])
for currency, value in data['rates'].items():
    df = df.append({'Currency': currency,
               'Rate': value}, ignore_index=True)
# Out:
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,
# /var/folders/f5/m7mfs5lx0gnbmf21kcrw48sr0000gn/T/ipykernel_73381/788385117.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Currency': currency,

# %%
df.head()
# Out:
#   Currency        Rate
# 0      AED    3.961143
# 1      AFN   90.085381
# 2      ALL  109.549130
# 3      AMD  419.509837
# 4      ANG    1.954482

# %%
# Drop unnescessary columns
df.set_index("Currency", inplace=True, drop=True)
df
# Out:
#                  Rate
# Currency
# AED          3.961143
# AFN         90.085381
# ALL        109.549130
# AMD        419.509837
# ANG          1.954482
# ...               ...
# YER        269.990358
# ZAR         20.332670
# ZMK       9707.364242
# ZMW         21.228650
# ZWL        347.261101
#
# [170 rows x 1 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
def to_csv(file, df):
    df.to_csv(file)  
to_csv("exchange_rates_1.csv", df)

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# | | Rates |
# | ------- | ------- |
# |  AED| 4.398618    |
# |  AFN| 92.917693   |
# |  ALL| 123.099093  |
# |  AMD| 621.935674  |
# |  ANG| 2.149648    |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url|
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR    |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork899-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
